# %%
# How to run virtualenv with jupyter notebook for the purposes of gcloud api
# first install virtualenv, create and switch to env
# pip install ipykernel
# python -m ipykernel install --user --name=my-virtualenv-name
# when inside ipynb, change kernel to desired env

# %%
# classification on test paragraph
text = "Late last month, a new bistro bar and restaurant concept by the name of Escobar opened its doors at China Square Central. In case you don’t know by its name already, it’s a bar with a theme that revolves around everything Pablo Escobar, the real-life Colombian drug lord who enjoyed a recent resurgence in popularity thanks to beloved Netflix series Narcos. But with murals dedicated to The King of Cocaine and a themed menu with offerings such as “Stab in Your Heart burger” and “Don Corleone” pizza, one would wonder if it’s problematic to celebrate a narcoterrorist who was responsible for thousands of deaths and turned Colombia into the murder capital of the world during the height of his power."
#classify(text)

# %%
# newspaper api for article scraping
from newspaper import Article

# %%
url = input()
article = Article(url)
article.download()
article.parse()
#article.authors
#article.publish_date
#article.text

# %%
article.text
# Out:
# 'In case you didn’t know, Subway Singapore has shown interest in going halal (which means “permissible” in Arabic).\n\nIf they do go halal, they will be following in the footsteps of Subway chains in London and Malaysia.\n\nJoy in Singapore\n\nNow, this news brought waves of joy to the Singapore Muslim community online:\n\nAdvertisement\n\nAnd brought relief to some of the Muslims out there who were begrudgingly judged for their “no pork no lard” lifestyle.\n\nHappy ending, right? Wrong.\n\nNon-halal eatery legacy issues\n\nEnter patrons of the fast-food chain that has been non-halal for 22 years.\n\nSo here’s why I don’t really care if Subway goes halal or remains a non-halal establishment.\n\nThere are substitutes (pun intended)\n\nSubway sells sandwiches, not some complicated gastronomic fare.\n\nSandwiches are easily made by oneself.\n\nBut if that’s too much of a task, there are other halal/ Muslim-owned sandwich places such as Toasties and Watsub, whose main customers are Muslims who can’t eat Subway because, you know, tak halal.\n\nAnd if a major fast food conglomerate like Subway decides to be halal-certified, these local eateries can potentially lose their target market.\n\nMoral of the story: #SupportLocal.\n\nThe move to halal isn’t even confirmed\n\nIf you read the article properly, Subway is just showing interest and have not submitted any formal applications.\n\nStill can’t see it? Don’t worry, I’ve blown it up for you.\n\nGranted, Subway Singapore now has an extensive list of restaurants serving pork-free protein, but that still doesn’t mean that the meats are halal-certified.\n\nYou see, halal is more than just the type of meat that Muslims are allowed to consume.\n\nWhile the halal certification requirements in Singapore are complex, the basic criteria do not just require the raw ingredients to be halal, but that the utensils (such as the crockery, microwave oven, frying pan etc.) must not be cross-contaminated with non-halal items.\n\nThis, we figure, will take a while for Subway to replace as there are more than 50 branches.\n\nIf they are positively going to go halal, that is.\n\nSo, let’s save our energy and not fight about it unless they 100 percent plus chop are going halal.\n\nPork-loving people are entitled to eat pork\n\nNow, let’s admit it: This saga is blowing way out of proportion because non-Muslims expressed their desire for pork to remain in one of the few non-halal fast food chains.\n\nThe flame was fanned harder when some Muslims saw this tweet:\n\nAnd this, in my unpopular opinion, is fair as it is a matter of personal dietary preferences.\n\nIt definitely was not fuelled by racism or any sort of discrimination, for that matter.\n\nIn fact, just like how Muslims are entitled to have a new halal fast food option, this dude right here is entitled to share and retain his love of pork.\n\nAnd these replies to the same tweet, which are apparently posted by Singaporean Muslims, got personal.\n\nTranslation of last sentence: “Not long from now, you will look like a pig too.”\n\n“No wonder your face like pig, you ate too much pork, lol. You eat non-halal food we never say anything but when we want halal food you complain. What an attitude.”\n\nAll this hate for a sandwich. Sad.\n\nAdvertisement\n\nMinding their own business\n\nIf Subway goes halal, Singaporean Muslims will have the convenience of having a grab-and-go sandwich since Subway is literally everywhere.\n\nHowever, before anything else, Subway is a business and businesses mainly get set up to make profits.\n\nPetitions were made for Subway to go halal in Singapore in the past, and Subway has acknowledged the demand for it back in 2010:\n\nAnd of course, they decided not to because going halal will “increase (our) operational costs”.\n\nForking out more to cater to about 15 percent of the population obviously was not profitable then.\n\nWhile we don’t know why Subway decided to change their stand eight years on, we’re pretty sure it’s mostly ...

# %%
import snippets
snippets.classify_text(article.text)
# Out:
# ====================
# name            : /Food & Drink
# confidence      : 0.5099999904632568

# %%
snippets.entities_text(article.text)
# Out:
# ====================
# name            : Subway Singapore
# type            : ORGANIZATION
# metadata        : {'mid': '/m/0f7q4', 'wikipedia_url': 'https://en.wikipedia.org/wiki/Subway_(restaurant)'}
# salience        : 0.3675355017185211
# wikipedia_url   : https://en.wikipedia.org/wiki/Subway_(restaurant)
# ====================
# name            : non-Muslims
# type            : PERSON
# metadata        : {'mid': '/m/04y29', 'wikipedia_url': 'https://en.wikipedia.org/wiki/Muslim'}
# salience        : 0.13162623345851898
# wikipedia_url   : https://en.wikipedia.org/wiki/Muslim
# ====================
# name            : fast-food chain
# type            : OTHER
# metadata        : {}
# salience        : 0.03419104963541031
# wikipedia_url   : -
# ====================
# name            : Subway Singapore
# type            : LOCATION
# metadata        : {'mid': '/m/06t2t', 'wikipedia_url': 'https://en.wikipedia.org/wiki/Singapore'}
# salience        : 0.02174702286720276
# wikipedia_url   : https://en.wikipedia.org/wiki/Singapore
# ====================
# name            : matter
# type            : OTHER
# metadata        : {}
# salience        : 0.019078481942415237
# wikipedia_url   : -
# ====================
# name            : sandwiches
# type            : OTHER
# metadata        : {}
# salience        : 0.015372558496892452
# wikipedia_url   : -
# ====================
# name            : case
# type            : OTHER
# metadata        : {}
# salience        : 0.013601062819361687
# wikipedia_url   : -
# ====================
# name            : sister chain
# type            : ORGANIZATION
# metadata        : {}
# salience        : 0.013533194549381733
# wikipedia_url   : -
# ====================
# name            : interest
# type            : OTHER
# metadata        : {}
# salience        : 0.011621937155723572
# wikipedia_url   : -
# ====================
# name            : pork
# type            : OTHER
# metadata        : {}
# salience        : 0.010077210143208504
# wikipedia_url   : -
# ====================
# name            : food
# type            : OTHER
# metadata        : {}
# salience        : 0.009389791637659073
# wikipedia_url   : -
# ====================
# name            : some
# type            : OTHER
# metadata        : {}
# salience        : 0.009168232791125774
# wikipedia_url   : -
# ====================
# name            : Subway chains
# type            : LOCATION
# metadata        : {}
# salience        : 0.00875570997595787
# wikipedia_url   : -
# ====================
# name            : pork
# type            : OTHER
# metadata        : {}
# salience        : 0.00861811637878418
# wikipedia_url   : -
# ====================
# name            : waves
# type            : OTHER
# metadata        : {}
# salience        : 0.008481486700475216
# wikipedia_url   : -
# ====================
# name            : relief
# type            : OTHER
# metadata        : {}
# salience        : 0.008438114076852798
# wikipedia_url   : -
# ====================
# name            : dude
# type            : PERSON
# metadata        : {}
# salience        : 0.008237858302891254
# wikipedia_url   : -
# ====================
# name            : Arabic
# type            : OTHER
# metadata        : {'mid': '/m/0jzc', 'wikipedia_url': 'https://en.wikipedia.org/wiki/Arabic'}
# salience        : 0.008066795766353607
# wikipedia_url   : https://en.wikipedia.org/wiki/Arabic
# ====================
# name            : community
# type            : PERSON
# metadata        : {}
# salience        : 0.00733731035143137
# wikipedia_url   : -
# ====================
# name            : joy
# type            : OTHER
# metadata        : {}
# salience        : 0.00733731035143137
# wikipedia_url   : -
# ====================
# name            : Advertisement
# type            : WORK_OF_ART
# metadata        : {}
# salience        : 0.007316627539694309
# wikipedia_url   : -
# ====================
# name            : eateries
# type            : ORGANIZATION
# metadata        : {}
# salience        : 0.007012320216745138
# wikipedia_url   : -
# ====================
# name            : sandwich
# type            : OTHER
# metadata        : {}
# salience        : 0.006826057098805904
# wikipedia_url   : -
# ====================
# name            : sandwich
# type            : OTHER
# metadata        : {}
# salience        : 0.00682431273162365
# wikipedia_url   : -
# ====================
# name            : loaf
# type            : OTHER
# metadata        : {}
# salience        : 0.006822602823376656
# wikipedia_url   : -
# ====================
# name            : Singapore Muslim
# type            : PERSON
# metadata        : {}
# salience        : 0.006667240988463163
# wikipedia_url   : -
# ====================
# name            : replies
# type            : WORK_OF_ART
# metadata        : {}
# salience        : 0.006641332991421223
# wikipedia_url   : -
# ====================
# name            : footsteps
# type            : OTHER
# metadata        : {}
# salience        : 0.006477642338722944
# wikipedia_url   : -
# ====================
# name            : lard
# type            : OTHER
# metadata        : {}
# salience        : 0.006388206034898758
# wikipedia_url   : -
# ====================
# name            : lifestyle
# type            : OTHER
# metadata        : {}
# salience        : 0.006388206034898758
# wikipedia_url   : -
# ====================
# name            : eatery legacy issues
# type            : OTHER
# metadata        : {}
# salience        : 0.006355510093271732
# wikipedia_url   : -
# ====================
# name            : patrons
# type            : PERSON
# metadata        : {}
# salience        : 0.0063470411114394665
# wikipedia_url   : -
# ====================
# name            : #SupportLocal
# type            : OTHER
# metadata        : {}
# salience        : 0.005422291811555624
# wikipedia_url   : -
# ====================
# name            : news
# type            : OTHER
# metadata        : {}
# salience        : 0.0048936596140265465
# wikipedia_url   : -
# ====================
# name            : sandwich
# type            : OTHER
# metadata        : {}
# salience        : 0.0047228275798261166
# wikipedia_url   : -
# ====================
# name            : Joy
# type            : PERSON
# metadata        : {}
# salience        : 0.004363012500107288
# wikipedia_url   : -
# ====================
# name            : type
# type            : OTHER
# metadata        : {}
# salience        : 0.004125290084630251
# wikipedia_url   : -
# ====================
# name            : people
# type            : PERSON
# metadata        : {}
# salience        : 0.004049698356539011
# wikipedia_url   : -
# ====================
# name            : London
# type            : LOCATION
# metadata        : {'mid': '/m/04jpl', 'wikipedia_url': 'https://en.wikipedia.org/wiki/London'}
# salience        : 0.0038372559938579798
# wikipedia_url   : https://en.wikipedia.org/wiki/London
# ====================
# name            : Malaysia
# type            : LOCATION
# metadata        : {'mid': '/m/09pmkv', 'wikipedia_url': 'https://en.wikipedia.org/wiki/Malaysia'}
# salience        : 0.0038372559938579798
# wikipedia_url   : https://en.wikipedia.org/wiki/Malaysia
# ====================
# name            : halal
# type            : OTHER
# metadata        : {}
# salience        : 0.0032610835041850805
# wikipedia_url   : -
# ====================
# name            : halal
# type            : OTHER
# metadata        : {}
# salience        : 0.0032535579521209
# wikipedia_url   : -
# ====================
# name            : much
# type            : OTHER
# metadata        : {}
# salience        : 0.0032085555139929056
# wikipedia_url   : -
# ====================
# name            : move
# type            : OTHER
# metadata        : {}
# salience        : 0.0030996708665043116
# wikipedia_url   : -
# ====================
# name            : establishment
# type            : ORGANIZATION
# metadata        : {}
# salience        : 0.0027667460963129997
# wikipedia_url   : -
# ====================
# name            : story
# type            : OTHER
# metadata        : {}
# salience        : 0.002751522697508335
# wikipedia_url   : -
# ====================
# name            : criteria
# type            : OTHER
# metadata        : {}
# salience        : 0.002686497289687395
# wikipedia_url   : -
# ====================
# name            : halal
# type            : OTHER
# metadata        : {}
# salience        : 0.0026819424238055944
# wikipedia_url   : -
# ====================
# name            : target market
# type            : OTHER
# metadata        : {}
# salience        : 0.002666328800842166
# wikipedia_url   : -
# ====================
# name            : pun
# type            : OTHER
# metadata        : {}
# salience        : 0.002418008167296648
# wikipedia_url   : -
# ====================
# name            : fare
# type            : OTHER
# metadata        : {}
# salience        : 0.0024155559949576855
# wikipedia_url   : -
# ====================
# name            : Toasties
# type            : LOCATION
# metadata        : {}
# salience        : 0.0024111780803650618
# wikipedia_url   : -
# ====================
# name            : task
# type            : OTHER
# metadata        : {}
# salience        : 0.0024111780803650618
# wikipedia_url   : -
# ====================
# name            : pork
# type            : OTHER
# metadata        : {}
# salience        : 0.002328725066035986
# wikipedia_url   : -
# ====================
# name            : fast food conglomerate
# type            : ORGANIZATION
# metadata        : {}
# salience        : 0.0022900893818587065
# wikipedia_url   : -
# ====================
# name            : chop
# type            : OTHER
# metadata        : {}
# salience        : 0.0022749491035938263
# wikipedia_url   : -
# ====================
# name            : substitutes
# type            : OTHER
# metadata        : {}
# salience        : 0.0022695029620081186
# wikipedia_url   : -
# ====================
# name            : customers
# type            : PERSON
# metadata        : {}
# salience        : 0.0022630919702351093
# wikipedia_url   : -
# ====================
# name            : sandwich places
# type            : LOCATION
# metadata        : {}
# salience        : 0.0022630919702351093
# wikipedia_url   : -
# ====================
# name            : article
# type            : WORK_OF_ART
# metadata        : {}
# salience        : 0.0021998314186930656
# wikipedia_url   : -
# ====================
# name            : fast food chains
# type            : OTHER
# metadata        : {}
# salience        : 0.0021831814665347338
# wikipedia_url   : -
# ====================
# name            : utensils
# type            : OTHER
# metadata        : {}
# salience        : 0.001981779234483838
# wikipedia_url   : -
# ====================
# name            : meat
# type            : OTHER
# metadata        : {}
# salience        : 0.0018502749735489488
# wikipedia_url   : -
# ====================
# name            : desire
# type            : OTHER
# metadata        : {}
# salience        : 0.0018091234378516674
# wikipedia_url   : -
# ====================
# name            : meats
# type            : OTHER
# metadata        : {}
# salience        : 0.0017375918105244637
# wikipedia_url   : -
# ====================
# name            : love
# type            : OTHER
# metadata        : {}
# salience        : 0.001716839731670916
# wikipedia_url   : -
# ====================
# name            : protein
# type            : OTHER
# metadata        : {}
# salience        : 0.0017039456870406866
# wikipedia_url   : -
# ====================
# name            : tweet
# type            : WORK_OF_ART
# metadata        : {}
# salience        : 0.0016874313587322831
# wikipedia_url   : -
# ====================
# name            : matter
# type            : OTHER
# metadata        : {}
# salience        : 0.0016860510222613811
# wikipedia_url   : -
# ====================
# name            : tweet
# type            : WORK_OF_ART
# metadata        : {}
# salience        : 0.0016847553197294474
# wikipedia_url   : -
# ====================
# name            : pig
# type            : OTHER
# metadata        : {}
# salience        : 0.0016841362230479717
# wikipedia_url   : -
# ====================
# name            : pig
# type            : OTHER
# metadata        : {}
# salience        : 0.001683534705080092
# wikipedia_url   : -
# ====================
# name            : face
# type            : OTHER
# metadata        : {}
# salience        : 0.001683534705080092
# wikipedia_url   : -
# ====================
# name            : applications
# type            : OTHER
# metadata        : {}
# salience        : 0.001664367620833218
# wikipedia_url   : -
# ====================
# name            : restaurants
# type            : LOCATION
# metadata        : {}
# salience        : 0.0016196750802919269
# wikipedia_url   : -
# ====================
# name            : list
# type            : OTHER
# metadata        : {}
# salience        : 0.0016196750802919269
# wikipedia_url   : -
# ====================
# name            : items
# type            : OTHER
# metadata        : {}
# salience        : 0.0016178889200091362
# wikipedia_url   : -
# ====================
# name            : crockery
# type            : OTHER
# metadata        : {}
# salience        : 0.0016178889200091362
# wikipedia_url   : -
# ====================
# name            : microwave oven
# type            : CONSUMER_GOOD
# metadata        : {}
# salience        : 0.0016178889200091362
# wikipedia_url   : -
# ====================
# name            : frying pan
# type            : CONSUMER_GOOD
# metadata        : {}
# salience        : 0.0016178889200091362
# wikipedia_url   : -
# ====================
# name            : energy
# type            : OTHER
# metadata        : {}
# salience        : 0.0016154743498191237
# wikipedia_url   : -
# ====================
# name            : proportion
# type            : OTHER
# metadata        : {}
# salience        : 0.0016140112420544028
# wikipedia_url   : -
# ====================
# name            : way
# type            : OTHER
# metadata        : {}
# salience        : 0.0016140112420544028
# wikipedia_url   : -
# ====================
# name            : saga
# type            : WORK_OF_ART
# metadata        : {}
# salience        : 0.0016140112420544028
# wikipedia_url   : -
# ====================
# name            : one
# type            : OTHER
# metadata        : {}
# salience        : 0.0016140112420544028
# wikipedia_url   : -
# ====================
# name            : flame
# type            : OTHER
# metadata        : {}
# salience        : 0.0016133175231516361
# wikipedia_url   : -
# ====================
# name            : certification requirements
# type            : OTHER
# metadata        : {}
# salience        : 0.0015184931689873338
# wikipedia_url   : -
# ====================
# name            : branches
# type            : OTHER
# metadata        : {}
# salience        : 0.0015177072491496801
# wikipedia_url   : -
# ====================
# name            : preferences
# type            : OTHER
# metadata        : {}
# salience        : 0.0014756680466234684
# wikipedia_url   : -
# ====================
# name            : opinion
# type            : OTHER
# metadata        : {}
# salience        : 0.0014756680466234684
# wikipedia_url   : -
# ====================
# name            : discrimination
# type            : OTHER
# metadata        : {}
# salience        : 0.0014750739792361856
# wikipedia_url   : -
# ====================
# name            : sort
# type            : OTHER
# metadata        : {}
# salience        : 0.0014750739792361856
# wikipedia_url   : -
# ====================
# name            : racism
# type            : OTHER
# metadata        : {}
# salience        : 0.0014750739792361856
# wikipedia_url   : -
# ====================
# name            : fact
# type            : OTHER
# metadata        : {}
# salience        : 0.001474498538300395
# wikipedia_url   : -
# ====================
# name            : fast food option
# type            : OTHER
# metadata        : {}
# salience        : 0.001474498538300395
# wikipedia_url   : -
# ====================
# name            : sentence
# type            : OTHER
# metadata        : {}
# salience        : 0.0014733986463397741
# wikipedia_url   : -
# ====================
# name            : Translation
# type            : OTHER
# metadata        : {}
# salience        : 0.0014733986463397741
# wikipedia_url   : -
# ====================
# name            : Watsub
# type            : OTHER
# metadata        : {}
# salience        : 0.0014273616252467036
# wikipedia_url   : -
# ====================
# name            : interest
# type            : OTHER
# metadata        : {}
# salience        : 0.001385560492053628
# wikipedia_url   : -
# ====================
# name            : more
# type            : OTHER
# metadata        : {}
# salience        : 0.0013780957087874413
# wikipedia_url   : -
# ====================
# name            : community
# type            : OTHER
# metadata        : {}
# salience        : 0.001253045629709959
# wikipedia_url   : -
# ====================
# name            : demand
# type            : OTHER
# metadata        : {}
# salience        : 0.001253045629709959
# wikipedia_url   : -
# ====================
# name            : profitability
# type            : OTHER
# metadata        : {}
# salience        : 0.001253045629709959
# wikipedia_url   : -
# ====================
# name            : news
# type            : OTHER
# metadata        : {}
# salience        : 0.001251774257980287
# wikipedia_url   : -
# ====================
# name            : food
# type            : OTHER
# metadata        : {}
# salience        : 0.00124342180788517
# wikipedia_url   : -
# ====================
# name            : costs
# type            : OTHER
# metadata        : {}
# salience        : 0.0010968182468786836
# wikipedia_url   : -
# ====================
# name            : population
# type            : PERSON
# metadata        : {}
# salience        : 0.0010965191759169102
# wikipedia_url   : -
# ====================
# name            : stand
# type            : OTHER
# metadata        : {}
# salience        : 0.0010962263913825154
# wikipedia_url   : -
# ====================
# name            : flat
# type            : LOCATION
# metadata        : {}
# salience        : 0.0010959396604448557
# wikipedia_url   : -
# ====================
# name            : ballot
# type            : OTHER
# metadata        : {}
# salience        : 0.0010959396604448557
# wikipedia_url   : -
# ====================
# name            : dash
# type            : CONSUMER_GOOD
# metadata        : {}
# salience        : 0.001095383777283132
# wikipedia_url   : -
# ====================
# name            : bread
# type            : CONSUMER_GOOD
# metadata        : {}
# salience        : 0.001095383777283132
# wikipedia_url   : -
# ====================
# name            : selection
# type            : EVENT
# metadata        : {}
# salience        : 0.001095383777283132
# wikipedia_url   : -
# ====================
# name            : sauces
# type            : OTHER
# metadata        : {}
# salience        : 0.001095383777283132
# wikipedia_url   : -
# ====================
# name            : vegetables
# type            : OTHER
# metadata        : {}
# salience        : 0.001095383777283132
# wikipedia_url   : -
# ====================
# name            : cold cuts
# type            : OTHER
# metadata        : {}
# salience        : 0.001095383777283132
# wikipedia_url   : -
# ====================
# name            : some
# type            : PERSON
# metadata        : {}
# salience        : 0.001088299322873354
# wikipedia_url   : -
# ====================
# name            : story
# type            : OTHER
# metadata        : {}
# salience        : 0.0010071604046970606
# wikipedia_url   : -
# ====================
# name            : establishment
# type            : ORGANIZATION
# metadata        : {}
# salience        : 0.0008663204498589039
# wikipedia_url   : -
# ====================
# name            : people
# type            : PERSON
# metadata        : {}
# salience        : 0.000865715614054352
# wikipedia_url   : -
# ====================
# name            : ingredients
# type            : OTHER
# metadata        : {}
# salience        : 0.0007952332962304354
# wikipedia_url   : -
# ====================
# name            : food
# type            : OTHER
# metadata        : {}
# salience        : 0.0007919430499896407
# wikipedia_url   : -
# ====================
# name            : sandwich
# type            : OTHER
# metadata        : {}
# salience        : 0.0007914144080132246
# wikipedia_url   : -
# ====================
# name            : sandwich
# type            : OTHER
# metadata        : {}
# salience        : 0.0007904348312877119
# wikipedia_url   : -
# ====================
# name            : pork
# type            : OTHER
# metadata        : {}
# salience        : 0.0007620341493748128
# wikipedia_url   : -
# ====================
# name            : egg mayonnaise sub
# type            : OTHER
# metadata        : {}
# salience        : 0.0007575287600047886
# wikipedia_url   : -
# ====================
# name            : tuna
# type            : OTHER
# metadata        : {}
# salience        : 0.0007575287600047886
# wikipedia_url   : -
# ====================
# name            : image
# type            : WORK_OF_ART
# metadata        : {}
# salience        : 0.000756854482460767
# wikipedia_url   : -
# ====================
# name            : page
# type            : OTHER
# metadata        : {}
# salience        : 0.000756854482460767
# wikipedia_url   : -
# ====================
# name            : trivia
# type            : OTHER
# metadata        : {}
# salience        : 0.0007565344567410648
# wikipedia_url   : -
# ====================
# name            : alternatives
# type            : OTHER
# metadata        : {}
# salience        : 0.0007111395243555307
# wikipedia_url   : -
# ====================
# name            : BTO
# type            : ORGANIZATION
# metadata        : {}
# salience        : 0.0006486264755949378
# wikipedia_url   : -
# ====================
# name            : business
# type            : OTHER
# metadata        : {}
# salience        : 0.0006051169475540519
# wikipedia_url   : -
# ====================
# name            : businesses
# type            : ORGANIZATION
# metadata        : {}
# salience        : 0.0006047599017620087
# wikipedia_url   : -
# ====================
# name            : Petitions
# type            : OTHER
# metadata        : {}
# salience        : 0.0005530608468689024
# wikipedia_url   : -
# ====================
# name            : anything
# type            : OTHER
# metadata        : {}
# salience        : 0.0005512245115824044
# wikipedia_url   : -
# ====================
# name            : Advertisement
# type            : WORK_OF_ART
# metadata        : {}
# salience        : 0.0005505071021616459
# wikipedia_url   : -
# ====================
# name            : anything
# type            : OTHER
# metadata        : {}
# salience        : 0.0005500141414813697
# wikipedia_url   : -
# ====================
# name            : demand
# type            : OTHER
# metadata        : {}
# salience        : 0.0005498573882505298
# wikipedia_url   : -
# ====================
# name            : Facebook
# type            : OTHER
# metadata        : {'mid': '/m/02y1vz', 'wikipedia_url': 'https://en.wikipedia.org/wiki/Facebook'}
# salience        : 0.0005120104178786278
# wikipedia_url   : https://en.wikipedia.org/wiki/Facebook
# ====================
# name            : attitude
# type            : OTHER
# metadata        : {}
# salience        : 0.0004820578033104539
# wikipedia_url   : -
# ====================
# name            : hate
# type            : OTHER
# metadata        : {}
# salience        : 0.00048189895460382104
# wikipedia_url   : -
# ====================
# name            : convenience
# type            : OTHER
# metadata        : {}
# salience        : 0.00048130241339094937
# wikipedia_url   : -
# ====================
# name            : course
# type            : OTHER
# metadata        : {}
# salience        : 0.0004808907979167998
# wikipedia_url   : -
# ====================
# name            :  ̄\
# type            : OTHER
# metadata        : {}
# salience        : 0.0004480119969230145
# wikipedia_url   : -
# ====================
# name            : Random
# type            : ORGANIZATION
# metadata        : {}
# salience        : 0.0004477254406083375
# wikipedia_url   : -
# ====================
# name            : Changi Airport
# type            : LOCATION
# metadata        : {'mid': '/m/012vsw', 'wikipedia_url': 'https://en.wikipedia.org/wiki/Singapore_Changi_Airport'}
# salience        : 0.0004477254406083375
# wikipedia_url   : https://en.wikipedia.org/wiki/Singapore_Changi_Airport
# ====================
# name            : profits
# type            : OTHER
# metadata        : {}
# salience        : 0.00042675729491747916
# wikipedia_url   : -
# ====================
# name            : everywhere
# type            : LOCATION
# metadata        : {}
# salience        : 0.0003687333664856851
# wikipedia_url   : -
